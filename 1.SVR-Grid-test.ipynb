# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset = dataset.astype(int)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-1.5330973 , -0.36100765, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.278355  , -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.51612426,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.84052963, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.75787698, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.95941426, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
regressor=SVR()
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [0.001, 0.01, 0.1, 1, 'scale', 'auto'],
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid']}

grid=GridSearchCV(SVR(),param_grid, refit= True, verbose=3, n_jobs=-1)    
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'gamma': [0.001, 0.01, 0.1, 1, 'scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_Score value for the best parameter{}:".format(grid.best_params_))
# Out:
# The R_Score value for the best parameter{'C': 100, 'gamma': 1, 'kernel': 'poly'}:

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.195374      0.257008         0.016336        0.022087      0.1
# 1        0.339051      0.387643         0.017235        0.002953      0.1
# 2        0.083839      0.030899         0.005663        0.000402      0.1
# 3        0.095716      0.028769         0.008530        0.001763      0.1
# 4        0.073218      0.021330         0.012754        0.009989      0.1
# ..            ...           ...              ...             ...      ...
# 91       0.135597      0.106482         0.009535        0.000598    100.0
# 92       0.343409      0.427351         0.006764        0.000314    100.0
# 93       0.071320      0.003112         0.021859        0.005477    100.0
# 94       0.066210      0.006667         0.006769        0.000288    100.0
# 95       0.084963      0.007709         0.009787        0.000936    100.0
#
#    param_gamma param_kernel  \
# 0        0.001       linear
# 1        0.001          rbf
# 2        0.001         poly
# 3        0.001      sigmoid
# 4         0.01       linear
# ..         ...          ...
# 91       scale      sigmoid
# 92        auto       linear
# 93        auto          rbf
# 94        auto         poly
# 95        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}          -0.035817
# 1         {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}          -0.041629
# 2        {'C': 0.1, 'gamma': 0.001, 'kernel': 'poly'}          -0.041640
# 3     {'C': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}          -0.041635
# 4       {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}          -0.035817
# ..                                                ...                ...
# 91  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.481175
# 92    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.584840
# 93       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300124
# 94      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.537814
# 95   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.482712
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.031015          -0.141311          -0.132729
# 1           -0.038077          -0.148680          -0.138663
# 2           -0.038091          -0.148695          -0.138675
# 3           -0.038084          -0.148688          -0.138669
# 4           -0.031015          -0.141311          -0.132729
# ..                ...                ...                ...
# 91           0.561849           0.429295           0.451834
# 92           0.656088           0.553185           0.577115
# 93           0.339544           0.174257           0.217017
# 94           0.574688           0.470001           0.532987
# 95           0.560842           0.433137           0.449720
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.135726        -0.095320        0.050642               54
# 1           -0.142116        -0.101833        0.050721               89
# 2           -0.142129        -0.101846        0.050721               96
# 3           -0.142122        -0.101840        0.050721               90
# 4           -0.135726        -0.095320        0.050642               54
# ..                ...              ...             ...              ...
# 91           0.431336         0.471098        0.049065               13
# 92           0.547448         0.583735        0.038807                3
# 93           0.183337         0.242856        0.065642               23
# 94           0.425034         0.508105        0.053456               11
# 95           0.431324         0.471547        0.048307               12
#
# [96 rows x 16 columns]

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoke_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 55
# BMI: 21
# Children: 6
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoke_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[19816479.37302144]

# %%
from sklearn.svm import SVR
regressor=SVR(C=100,gamma=1,kernel="poly")
   
regressor.fit(x_train,y_train)
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=100, gamma=1, kernel='poly')

# %%
y_pred=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.8570789384098867
